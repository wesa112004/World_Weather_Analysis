# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from config import weather_api_key


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
#create url for query with imperial units and city at the end
#url from https://openweathermap.org/appid
url = "http://api.openweathermap.org/data/2.5/weather?id=524901"
unit = "imperial"
query_url = f"{url}&appid={weather_api_key}&units={unit}&q="

# Lists for results
lat = []
lon = []
foundCities = []
temp = []
humidity = []
cloudiness = []
windSpeed = []
date = []
country = []

for city in cities:
    try:
        response = requests.get(query_url + city).json()
        lat.append(response["coord"]["lat"])
        lon.append(response["coord"]["lon"])
        temp.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        windSpeed.append(response["wind"]["speed"])
        date.append(response["dt"])
        country.append(response["sys"]["country"])
        foundCities.append(city)
        print(f"City processed: {city}")
    except:
        print(f"City NOT found: {city}")
# Out:
# City processed: kahului
# City processed: atuona
# City NOT found: taolanaro
# City processed: saskylakh
# City processed: chokurdakh
# City processed: bambous virieux
# City processed: bluff
# City processed: cabo san lucas
# City processed: olafsvik
# City processed: rikitea
# City processed: lesozavodsk
# City processed: opuwo
# City processed: bredasdorp
# City processed: hermanus
# City processed: cape town
# City processed: dawson creek
# City processed: paidha
# City processed: jardim
# City processed: berlevag
# City processed: ushuaia
# City processed: mataura
# City processed: aklavik
# City processed: qaanaaq
# City processed: broome
# City processed: punta arenas
# City processed: shingu
# City processed: sarankhola
# City processed: axim
# City processed: kaseda
# City processed: saint-philippe
# City processed: mar del plata
# City processed: kaeo
# City processed: new norfolk
# City processed: hilo
# City processed: goderich
# City processed: busselton
# City processed: avarua
# City NOT found: samusu
# City processed: bethel
# City processed: provideniya
# City processed: tagusao
# City processed: tuatapere
# City processed: kovdor
# City NOT found: marcona
# City processed: port hedland
# City processed: avera
# City processed: sao filipe
# City processed: kodiak
# City processed: hambantota
# City processed: baruun-urt
# City processed: ekhabi
# City processed: dakar
# City processed: faanui
# City processed: cidreira
# City processed: victoria
# City processed: oran
# City processed: tazovskiy
# City processed: codrington
# City processed: praia da vitoria
# City processed: ashcroft
# City processed: boguchany
# City processed: terra santa
# City processed: pangnirtung
# City processed: kapaa
# City processed: north myrtle beach
# City processed: severo-kurilsk
# City processed: cockburn town
# City processed: burgersdorp
# City processed: khatanga
# City processed: buala
# City NOT found: attawapiskat
# City processed: albany
# City processed: nikolskoye
# City processed: roncesvalles
# City processed: conceicao do araguaia
# City processed: suez
# City processed: surovatikha
# City NOT found: longlac
# City processed: sao jose da coroa grande
# City processed: tasiilaq
# City processed: evensk
# City processed: wanning
# City processed: lopukhiv
# City processed: puerto ayora
# City processed: coronado
# City processed: hobart
# City processed: sibolga
# City processed: yulara
# City processed: lompoc
# City processed: krasnoselkup
# City processed: meulaboh
# City processed: thompson
# City processed: pevek
# City processed: barrow
# City processed: fairbanks
# City processed: hay river
# City NOT found: saleaula
# City NOT found: tsihombe
# City processed: noumea
# City processed: great falls
# City NOT found: louisbourg
# City processed: port elizabeth
# City processed: riosucio
# City processed: lokosovo
# City processed: haines junction
# City NOT found: grand river south east
# City processed: la ronge
# City processed: nizhniy tsasuchey
# City processed: clyde river
# City processed: beloha
# City NOT found: toliary
# City processed: constitucion
# City processed: anju
# City processed: upernavik
# City NOT found: warqla
# City NOT found: illoqqortoormiut
# City NOT found: taburi
# City processed: dwarka
# City processed: dikson
# City processed: tutoia
# City processed: youhao
# City processed: port alfred
# City processed: isangel
# City processed: longyearbyen
# City processed: luderitz
# City processed: petropavlovsk-kamchatskiy
# City NOT found: belushya guba
# City processed: mahebourg
# City NOT found: amderma
# City processed: okhtyrka
# City processed: vaini
# City processed: madimba
# City processed: talnakh
# City processed: hasaki
# City processed: nongstoin
# City processed: carnarvon
# City processed: grand gaube
# City NOT found: nizhneyansk
# City processed: pisco
# City processed: phan thiet
# City processed: shimoda
# City processed: tautira
# City processed: yaroslavl
# City processed: miram shah
# City processed: joshimath
# City processed: kawalu
# City processed: port hardy
# City processed: ghanzi
# City processed: camana
# City processed: abaete
# City processed: jamestown
# City processed: pyu
# City processed: esperance
# City processed: nantucket
# City processed: ribeira grande
# City processed: ilulissat
# City processed: carutapera
# City processed: marsaxlokk
# City processed: panguna
# City processed: puerto penasco
# City processed: vila velha
# City processed: sola
# City processed: chippewa falls
# City processed: ocampo
# City processed: vao
# City processed: san andres
# City processed: tuktoyaktuk
# City processed: chahal
# City processed: namatanai
# City processed: bullhead city
# City processed: east london
# City processed: japura
# City processed: bermeo
# City processed: batemans bay
# City processed: langsa
# City processed: passos
# City processed: kieta
# City processed: pitea
# City processed: takoradi
# City processed: fort nelson
# City processed: yellowknife
# City processed: zhigansk
# City processed: hofn
# City processed: arraial do cabo
# City processed: manjacaze
# City processed: narsaq
# City processed: saldanha
# City processed: marovoay
# City processed: concordia
# City processed: portland
# City processed: ponta do sol
# City NOT found: alotau
# City processed: ancud
# City processed: jeremie
# City processed: guatire
# City processed: butaritari
# City processed: saint george
# City processed: tonj
# City processed: thinadhoo
# City processed: shar
# City processed: madisonville
# City processed: wonthaggi
# City processed: san juan
# City NOT found: barentsburg
# City processed: angicos
# City processed: guerrero negro
# City processed: norman wells
# City processed: hithadhoo
# City processed: kalat
# City processed: taylor
# City processed: saint-joseph
# City processed: dareda
# City processed: nikel
# City processed: boueni
# City processed: road town
# City processed: lavrentiya
# City processed: panacan
# City processed: georgetown
# City processed: touros
# City processed: bathsheba
# City processed: lebu
# City processed: hrebinka
# City processed: dauphin
# City processed: soyo
# City processed: vila franca do campo
# City processed: cherskiy
# City processed: morristown
# City processed: kholtoson
# City NOT found: bokspits
# City processed: salalah
# City processed: beitbridge
# City processed: grand-santi
# City processed: gizo
# City processed: tahta
# City processed: gravelbourg
# City processed: nelson bay
# City processed: port blair
# City processed: barcelos
# City processed: ossora
# City processed: caravelas
# City processed: nanortalik
# City processed: belyy yar
# City processed: zaragoza
# City processed: bengkulu
# City processed: kaitangata
# City processed: coari
# City processed: glendive
# City NOT found: erhlin
# City processed: shache
# City processed: bourail
# City NOT found: umzimvubu
# City processed: nioaque
# City processed: nivala
# City processed: cururupu
# City processed: baykit
# City processed: umba
# City processed: dunedin
# City processed: agua dulce
# City processed: riyadh
# City processed: srednekolymsk
# City processed: tianpeng
# City processed: zhezkazgan
# City processed: sayyan
# City processed: bambanglipuro
# City NOT found: halalo
# City processed: kavaratti
# City processed: gunnedah
# City processed: angoche
# City processed: fairview
# City processed: grindavik
# City processed: bakchar
# City processed: korla
# City processed: tilichiki
# City processed: nurlat
# City NOT found: sentyabrskiy
# City processed: pitimbu
# City processed: manadhoo
# City processed: namibe
# City processed: kasongo-lunda
# City NOT found: nguiu
# City processed: harper
# City processed: san policarpo
# City processed: dinhata
# City processed: tukrah
# City processed: rawson
# City processed: labytnangi
# City processed: buraydah
# City processed: panaba
# City processed: linden
# City processed: alekseyevsk
# City processed: novoagansk
# City NOT found: buqayq
# City processed: sobolevo
# City processed: lasa
# City processed: salta
# City processed: flinders
# City processed: yerbogachen
# City processed: sakyla
# City NOT found: valjala
# City processed: pyapon
# City processed: sutysky
# City processed: poso
# City processed: kedrovyy
# City processed: mariental
# City processed: copiapo
# City processed: tiksi
# City processed: najran
# City processed: pakokku
# City processed: san vicente
# City processed: klaksvik
# City processed: poum
# City processed: mount isa
# City processed: taltal
# City processed: kruisfontein
# City processed: isabela
# City processed: iqaluit
# City processed: mukhen
# City processed: kyra
# City processed: solnechnyy
# City NOT found: karaul
# City processed: beringovskiy
# City processed: college
# City processed: port lincoln
# City processed: chicama
# City processed: sinnamary
# City processed: berberati
# City processed: banjar
# City processed: hovd
# City processed: leningradskiy
# City processed: castro
# City processed: mustasaari
# City processed: patacamaya
# City processed: antalaha
# City processed: taksimo
# City processed: teguldet
# City NOT found: bo
# City processed: calderitas
# City processed: chimbarongo
# City processed: san cristobal
# City processed: shizunai
# City processed: zabol
# City processed: yar-sale
# City processed: bilibino
# City processed: mattru
# City processed: srandakan
# City processed: saint-louis
# City processed: esil
# City processed: lovozero
# City processed: arrifes
# City processed: gorontalo
# City processed: amapa
# City processed: coahuayana
# City processed: diego de almagro
# City processed: talara
# City processed: nisia floresta
# City processed: udachnyy
# City processed: veraval
# City processed: agadez
# City processed: nikolsk
# City processed: srednebelaya
# City NOT found: labutta
# City processed: mongo
# City processed: fortuna
# City processed: dickinson
# City processed: sakakah
# City processed: alexandria
# City processed: leo
# City processed: labuan
# City processed: katsuura
# City NOT found: tumannyy
# City processed: izumo
# City processed: capao bonito
# City processed: katobu
# City processed: chuy
# City processed: vardo
# City processed: kirkwood
# City processed: toba tek singh
# City processed: porto belo
# City NOT found: galchino
# City processed: palmer
# City processed: lazaro cardenas
# City processed: ukhta
# City processed: amuntai
# City processed: ust-nera
# City processed: sinnar
# City processed: bako
# City processed: tavda
# City processed: tandil
# City processed: puerto quijarro
# City processed: ferrol
# City processed: velingara
# City processed: paamiut
# City NOT found: grand centre
# City processed: souillac
# City processed: kulhudhuffushi
# City processed: pagudpud
# City processed: nambour
# City processed: mazyr
# City processed: sorong
# City processed: celestun
# City processed: hadejia
# City processed: porto walter
# City processed: yining
# City processed: manzanillo
# City processed: luancheng
# City processed: majene
# City processed: darhan
# City processed: the valley
# City processed: gogrial
# City processed: mayumba
# City processed: aguimes
# City processed: san patricio
# City processed: honiara
# City processed: airai
# City processed: oxilithos
# City processed: bahia blanca
# City processed: izhma
# City processed: tazmalt
# City processed: chabahar
# City processed: nishihara
# City processed: padang
# City processed: alofi
# City processed: luanda
# City processed: comodoro rivadavia
# City processed: banda aceh
# City processed: pervomayskoye
# City processed: saquena
# City processed: torbay
# City processed: honningsvag
# City processed: morondava
# City processed: beian
# City NOT found: samalaeulu
# City processed: oussouye
# City processed: savelugu
# City processed: jingdezhen
# City processed: tura
# City NOT found: ust-kamchatsk
# City processed: coihaique
# City processed: krasnoarmeysk
# City processed: lianran
# City processed: kinkala
# City processed: egvekinot
# City processed: malino
# City processed: boyabat
# City processed: los llanos de aridane
# City processed: eyl
# City processed: bayan
# City processed: la reforma
# City processed: aste
# City processed: erenhot
# City processed: te anau
# City processed: puerto baquerizo moreno
# City processed: corbelia
# City processed: wanaka
# City processed: altamira
# City processed: gallup
# City processed: port-gentil
# City processed: nioro
# City processed: yangambi
# City processed: barcelona
# City processed: moree
# City processed: aykhal
# City processed: moose factory
# City processed: plettenberg bay
# City processed: lodja
# City processed: yumen
# City processed: sitka
# City processed: bilma
# City processed: navahrudak
# City processed: arlit
# City processed: karratha
# City processed: chau doc
# City NOT found: mutsamudu
# City processed: carballo
# City processed: bunia
# City processed: brodokalmak
# City processed: sao joao da barra
# City processed: halifax
# City processed: mazurivka
# City NOT found: tambul
# City processed: ambilobe
# City processed: asau
# City processed: broken hill
# City NOT found: mys shmidta
# City NOT found: tabiauea
# City processed: artyom
# City processed: koumac
# City processed: karpathos
# City processed: farmington
# City processed: catemaco
# City processed: abnub
# City processed: ravar
# City processed: laguna
# City processed: khingansk
# City processed: flin flon
# City processed: kisangani
# City processed: sorland
# City processed: belur
# City processed: athenree
# City processed: muros
# City processed: abalak
# City processed: panguipulli
# City processed: xining
# City processed: brae
# City processed: ntungamo
# City processed: atar
# City processed: acari
# City NOT found: formoso do araguaia
# City NOT found: bolungarvik
# City processed: vaxjo
# City NOT found: tawkar
# City processed: cacu
# City processed: itarema
# City processed: el cope
# City processed: ortona
# City processed: gat
# City processed: vysokopillya
# City processed: sisimiut
# City processed: sept-iles
# City processed: belaya gora
# City processed: arroyo
# City processed: safranbolu
# City NOT found: slevik
# City processed: helena
# City processed: boende
# City processed: milkovo
# City processed: nagato
# City processed: garissa
# City processed: kavieng
# City processed: carauari
# City processed: pacifica
# City processed: geraldton
# City processed: gazli
# City processed: hazorasp
# City processed: uni
# City processed: adrar
# City processed: santa maria del oro
# City processed: yeppoon
# City processed: la teste-de-buch
# City processed: rivers
# City processed: bay city
# City processed: lagoa
# City processed: guadalupe y calvo
# City processed: ahipara
# City processed: huarmey
# City NOT found: yirol
# City processed: afsin
# City processed: jalu
# City processed: walvis bay
# City processed: hami
# City processed: bonfim
# City processed: mogadishu
# City processed: jericho
# City processed: meybod
# City processed: bom jesus
# City processed: buzmeyin
# City processed: ljig
# City processed: kamenka
# City processed: naters
# City NOT found: vaitupu
# City processed: beyneu
# City processed: gorele
# City processed: benton harbor
# City processed: independence
# City processed: shubarkuduk
# City processed: panjakent
# City processed: faya
# City processed: pilar
# City NOT found: atka
# City processed: sur
# City processed: urambo
# City processed: imeni vorovskogo
# City processed: linxia
# City NOT found: os
# City NOT found: cockburn harbour
# City processed: almaznyy
# City processed: kutum
# City processed: talcahuano
# City processed: berea
# City processed: wangaratta
# City processed: saurimo
# City processed: contamana
# City processed: havre-saint-pierre
# City processed: rudsar
# City processed: hsinchu
# City processed: rhyl
# City NOT found: kazalinsk
# City NOT found: sorvag
# City processed: amravati
# City processed: ygatimi
# City processed: central point
# City processed: zhanakorgan
# City processed: nemuro
# City processed: sholapur
# City processed: solano
# City processed: nikki
# City processed: kudahuvadhoo
# City NOT found: witrivier
# City processed: teya
# City processed: puerto colombia
# City processed: lorengau
# City processed: camacha
# City processed: kirakira
# City processed: morant bay

# %%
Weather_DF = pd.DataFrame({"City": foundCities,
                           "Country": country,
                           "Temperature": temp,
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Windspeed":windSpeed,
                           "Latitude": lat,
                           "Longitude": lon,
                           "Date": date
                          })
Weather_DF
# Out:
#                 City Country  Temperature  Humidity  Cloudiness  Windspeed  \
# 0            kahului      US        73.85        84          40      14.97
# 1             atuona      PF        78.44        74          93       7.63
# 2          saskylakh      RU        12.81        95         100      10.58
# 3         chokurdakh      RU       -18.08        97           6       4.90
# 4    bambous virieux      MU        78.22        94          75      25.32
# ..               ...     ...          ...       ...         ...        ...
# 549  puerto colombia      CO        77.09        81          99      18.68
# 550         lorengau      PG        82.63        77         100      17.76
# 551          camacha      PT        54.82       100          75       5.75
# 552         kirakira      SB        78.49        94         100      15.70
# 553       morant bay      JM        80.22        82          18      10.56
#
#      Latitude  Longitude        Date
# 0     20.8947  -156.4700  1648801957
# 1     -9.8000  -139.0333  1648801978
# 2     71.9167   114.0833  1648801978
# 3     70.6333   147.9167  1648801979
# 4    -20.3428    57.7575  1648801979
# ..        ...        ...         ...
# 549   10.9878   -74.9547  1648802244
# 550   -2.0226   147.2712  1648802244
# 551   33.0833   -16.3333  1648802245
# 552  -10.4544   161.9205  1648802245
# 553   17.8815   -76.4093  1648802246
#
# [554 rows x 9 columns]

# %%
# Export as (CSV).
Weather_DF.to_csv ("/Users/wesadams/Desktop/WeatherPy/World_Weather_Analysis/Weather_Database.csv")
